# %% [markdown]
# Task Day1

# %%
import requests
import pandas as pd
import re

# %% [markdown]
# Fetching News Data

# %%
url="https://newsapi.org/v2/everything?q=GazaStrip&from=2023-12-18&to=2024-01-03&sortBy=popularity&language=en&apiKey=7bced8b0892f439b86d0264b08dba53d"
r=requests.get(url)
r.content
# Out:
# b'{"status":"ok","totalResults":147,"articles":[{"source":{"id":null,"name":"Biztoc.com"},"author":"youtube.com","title":"IDF footage reportedly shows the destruction of tunnel network used by Hamas officials in Gaza","description":"IDF forces destroy the network of strategic tunnels in the Hamas Officials\' Square in the Gaza Strip. After revealing the Hamas ... #hamas #gazastrip","url":"https://biztoc.com/x/81e9d9fc7a237576","urlToImage":"https://c.biztoc.com/p/81e9d9fc7a237576/s.webp","publishedAt":"2023-12-22T10:52:11Z","content":"IDF forces destroy the network of strategic tunnels in the Hamas Officials\' Square in the Gaza Strip. After revealing the Hamas ...\\r\\n#hamas#gazastrip\\r\\nThis story appeared on youtube.com, ."},{"source":{"id":null,"name":"Biztoc.com"},"author":"pbs.org","title":"Airstrikes hit central Gaza camps as U.S. moves ahead with new weapons sale to Israel","description":"DEIR AL-BALAH, Gaza Strip (AP) \xe2\x80\x94 Israeli warplanes struck two urban refuge
# ...

# %% [markdown]
# Writing the Byte Data received in a file

# %%
with open("my_file.json", "wb") as binary_file:
   
    # Write bytes to file
    binary_file.write(r.content)

# %% [markdown]
# Reading the written file.

# %%
df1=pd.read_json('my_file.json')

# %% [markdown]
# Normalising the Articles field to get our required data

# %%
df2=pd.json_normalize(df1['articles'])
df2['analyze_component']=df2['title']+((df2['description'][:200] + '..') if len(df2['description']) > 200 else df2['description'])
# df2.head(50)

# %% [markdown]
# Filtered out the outdated Articles

# %%
df2 = df2.drop(df2[df2['content']=='[Removed]'].index)
df2.shape
# Out:
# (100, 10)

# %% [markdown]
# <!-- Now comes the sentiment Analysis Part
# We will try to do it three way, Probably. Let's see
# 1.) Lexicon Based Analysis
# 2.) Machine Learning
# 3.) Transformer Based -->

# %%
# import libraries
import pandas as pd

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

from nltk.stem import WordNetLemmatizer

# %%
# download nltk corpus (first time only)

# nltk.download('all')

# %%
#preprocess the text (Tokenize, StopWorRemoval, Lemmatization)
def preprocess(text):
    # tokenisation
    text=str(text)
    tokens=word_tokenize(text)
    
    #StopWords
    WithoutSW=[x for x in tokens if x not in stopwords.words('english')]

    #lemmatization
    lemetizer=WordNetLemmatizer()
    lemetized_list=[lemetizer.lemmatize(x) for x in WithoutSW]

    # Now that we have our Lemetized List, Join them to form the processed text which would then be analyzed
    processed_text = ' '.join(lemetized_list)

    return processed_text

# %%
df2
# Out:
#                    author                                              title  \
# 0             youtube.com  IDF footage reportedly shows the destruction o...
# 1                 pbs.org  Airstrikes hit central Gaza camps as U.S. move...
# 2                 pbs.org  The number of Israeli soldiers wounded in Gaza...
# 3            newsweek.com  What Was Israel Supposed to Do After Oct. 7? N...
# 4            newsweek.com  US doesn't need to tell Israel not to kill civ...
# ..                    ...                                                ...
# 95           newsweek.com               Eurovision faces threats over Israel
# 96  hollywoodreporter.com  Jerry Seinfeld Meets With Families of Israeli ...
# 97                pbs.org  Top Hamas leader visits Cairo as indirect talk...
# 98           politico.com  Weekend of combat in Gaza kills 14 Israeli sol...
# 99          investing.com  Israel says five Gaza hostages found dead in t...
#
# ...

# %%
df2['processed_text']=df2['analyze_component'].apply(preprocess)
df2['processed_text']
# Out:
# 0     IDF footage reportedly show destruction tunnel...
# 1     Airstrikes hit central Gaza camp U.S. move ahe...
# 2     The number Israeli soldier wounded Gaza mounti...
# 3     What Was Israel Supposed Do After Oct. 7 ? Not...
# 4     US n't need tell Israel kill civilian , army s...
#                             ...
# 95    Eurovision face threat IsraelEurovision boycot...
# 96    Jerry Seinfeld Meets With Families Israeli Hos...
# 97    Top Hamas leader visit Cairo indirect talk ano...
# 98    Weekend combat Gaza kill 14 Israeli soldier si...
# 99    Israel say five Gaza hostage found dead tunnel...
# Name: processed_text, Length: 100, dtype: object

# %%
analyzer=SentimentIntensityAnalyzer()
# Score=analyzer.polarity_scores("I do not like this Food one bit")
# Score

def Sen_Analyze(text):
    Sen_tag=""
    Score=analyzer.polarity_scores(text)['compound']
    if(Score<-0.2):
        Sen_tag="Negative"
    elif (Score>=-0.2 and Score<=0.2):
        Sen_tag="Neutral"
    else:
        Sen_tag="Positive"
    return Sen_tag
df2['count']=1
df2['Sentiment']=df2['processed_text'].apply(Sen_Analyze)

# %% [markdown]
# Random Analysis

# %%
df2
# Out:
#                    author                                              title  \
# 0             youtube.com  IDF footage reportedly shows the destruction o...
# 1                 pbs.org  Airstrikes hit central Gaza camps as U.S. move...
# 2                 pbs.org  The number of Israeli soldiers wounded in Gaza...
# 3            newsweek.com  What Was Israel Supposed to Do After Oct. 7? N...
# 4            newsweek.com  US doesn't need to tell Israel not to kill civ...
# ..                    ...                                                ...
# 95           newsweek.com               Eurovision faces threats over Israel
# 96  hollywoodreporter.com  Jerry Seinfeld Meets With Families of Israeli ...
# 97                pbs.org  Top Hamas leader visits Cairo as indirect talk...
# 98           politico.com  Weekend of combat in Gaza kills 14 Israeli sol...
# 99          investing.com  Israel says five Gaza hostages found dead in t...
#
# ...

# %%
Group_for_visualize=df2.groupby(['source.name','Sentiment']).count()
Group_for_visualize['count']
Group_for_visualize.reset_index(inplace=True)
Pivoted_Group=Group_for_visualize.pivot(index='source.name', columns='Sentiment', values='count')
Pivoted_Group['Negative'] = Pivoted_Group['Negative'].fillna(0)
Pivoted_Group['Positive'] = Pivoted_Group['Positive'].fillna(0)
Pivoted_Group['Neutral'] = Pivoted_Group['Neutral'].fillna(0)
Pivoted_Group
# Out:
# Sentiment    Negative  Neutral  Positive
# source.name
# Biztoc.com         77        3        20

# %% [markdown]
# Sending the Data to a database

# %%
# import sqlalchemy as db
from sqlalchemy import create_engine
connection_string = "mysql+mysqlconnector://root:Naman@localhost:3306/intern_task"
engine = create_engine(connection_string, echo=True)

# %%
df2['publishedAt'].fillna('2024-01-01')
dates=[]
for x in df2['publishedAt']:
    dates.append(x[0:10])
df2['Dates']=dates
df2
# Out:
#                    author                                              title  \
# 0             youtube.com  IDF footage reportedly shows the destruction o...
# 1                 pbs.org  Airstrikes hit central Gaza camps as U.S. move...
# 2                 pbs.org  The number of Israeli soldiers wounded in Gaza...
# 3            newsweek.com  What Was Israel Supposed to Do After Oct. 7? N...
# 4            newsweek.com  US doesn't need to tell Israel not to kill civ...
# ..                    ...                                                ...
# 95           newsweek.com               Eurovision faces threats over Israel
# 96  hollywoodreporter.com  Jerry Seinfeld Meets With Families of Israeli ...
# 97                pbs.org  Top Hamas leader visits Cairo as indirect talk...
# 98           politico.com  Weekend of combat in Gaza kills 14 Israeli sol...
# 99          investing.com  Israel says five Gaza hostages found dead in t...
#
# ...

# %%
Data_to_be_sent=df2[['author','url','title','description','Sentiment','Dates']]

# %%
Data_to_be_sent.to_sql(name='Intern_Task', con=engine,if_exists='replace')
# Out:
# 2024-01-17 13:37:18,681 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-17 13:37:18,685 INFO sqlalchemy.engine.Engine DESCRIBE `intern_task`.`Intern_Task`
# 2024-01-17 13:37:18,685 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-17 13:37:18,688 INFO sqlalchemy.engine.Engine DESCRIBE `intern_task`.`Intern_Task`
# 2024-01-17 13:37:18,689 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-17 13:37:18,691 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `intern_task`
# 2024-01-17 13:37:18,691 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-17 13:37:18,694 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `intern_task`
# 2024-01-17 13:37:18,695 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-17 13:37:18,708 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `Intern_Task`
# 2024-01-17 13:37:18,708 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-01-17 13:37:18,711 INFO sqlalchemy.engine.Engine
# DROP TABLE `Intern_Task`
# ...

# %%
from sqlalchemy.sql import text
with engine.connect() as con:
    # statement = text()
    rs=con.execute(text('select Sentiment,count(*) from Intern_Task group by Sentiment'))

    for row in rs:
        print(row)
# Out:
# 2024-01-17 13:37:29,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-01-17 13:37:29,107 INFO sqlalchemy.engine.Engine select Sentiment,count(*) from Intern_Task group by Sentiment
# 2024-01-17 13:37:29,107 INFO sqlalchemy.engine.Engine [generated in 0.00234s] {}
# ('Negative', 77)
# ('Positive', 20)
# ('Neutral', 3)
# 2024-01-17 13:37:29,109 INFO sqlalchemy.engine.Engine ROLLBACK
